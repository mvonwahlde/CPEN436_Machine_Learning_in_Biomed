# %% [markdown]
# # Cardiovascular Disease Detection

# %% [markdown]
# ## 1 - Problem Description
#
# Cardiovascular disease is a generic term that represents any sort of disorder that is associated with the heart. 695,000 people in the United States die each year due to cardiovascular disease. It is life-threatening and it is imporant to diagnose. That is why I have decided to build a machine learning model that can accurately predict whether a person has heart disease based on 12 key features.
#
# The dataset used to train the model is a cardiovascular disease dataset found on kaggle.com. The data was acquired from a multispecialty hospital in India. There are 1,000 total patient examples with 12 different features for each. The purpose for the compilation of this dataset was to generate a predictive machine-learning model to detect early-stage heart disease.

# %% [markdown]
# ## 2 - Biomedical Dataset and Preprocessing

# %% [markdown]
# ### 2.1 - Packages
#
# First, running the cell below will import the packages needed for this project.
# - [numpy](https://numpy.org/) is the fundamental package for scientific computing with Python.
# - [tensorflow](https://www.tensorflow.org/) a popular platform for machine learning.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# **Tensorflow and Keras**
# Tensorflow is a machine learning package developed by Google. In 2019, Google integrated Keras into Tensorflow and released Tensorflow 2.0. Keras is a framework developed independently by François Chollet that creates a simple, layer-centric interface to Tensorflow. This project will be using the Keras interface.

# %% [markdown]
# ### 2.2 - Dataset Desciption
#
# This dataset contains 1,000 patient examples, each with a patient ID, a classification, and the following 12 features:
# - Age: The patient's age in years
# - Gender: The patient's gender (0 - female, 1 - male)
# - Chest Pain Type: 0 - typical angina, 1 - atypical angina, 2 - non-anginal pain, 3 - asymptomatic
# - Resting Blood Pressure: The patients resting blood pressure (mmHg)
# - Serum Cholesterol: The patient's total amount of cholesterol in their blood (mg/dL)
# - Fasting Blood Sugar: 1 - greater than 120 mg/dL, 0 - not greater than 120 mg/dL
# - Resting Electrocardiogram Results: 0 - normal, 1 - having ST-T wave abnormality, 2 - showing probable or definite left ventricular hypertrophy
# - Maximum Heart Rate Achieved: The patient's max heart rate (BPM)
# - Exercise Induced Angina: 0 - no, 1 - yes
# - Old Peak ST: How low the ST segment is below the baseline
# - Slope of the Peak Exercise ST Segment: 1 - upsloping, 2 - flat, 3 - downsloping
# - Number of Major Vessels: 0, 1, 2, or 3 major vessels
#
# Each example provides a classification where a 0 indicates the absence of heart disease and a 1 indicates the presence of heart disease.
#
# There is no missing data in this dataset; however, there are many binary and nominal values that will need to be one-hot encoded. This will be discussed more later.

# %% [markdown]
# ### 2.3 - Loading the Data
#
# Before processing, we will load the data into two variables. The first, X, is an m x n matrix that stores each patient example and the 12 corresponding features (m examples, n features). The second, y, is an m x 1 array that provides a classification for each patient example (m examples). A 0 indicates the absence of heart disease and 1 indicates the presence of heart disease.

# %%
def load_data(filename):
    """
    Loads and formats data from the WDBC dataset

    Args:
    filename : relative path for the file that holds the data

    Returns:
    X : (ndarray Shape (m,n)) data, m examples by n features
    y : (array_like Shape (m,)) outputs, 1 == heart disease present, 0 == absent
    """
    # Load the data from the file
    data = np.loadtxt(filename, dtype=str, delimiter=',')

    # Store the 12 features from each example into a 2D matrix and convert the type to float
    X = np.array(data[1:,1:13])
    X = X.astype(float)

    # Store the outputs for each example and reshape the array to (m,)
    y = np.array(data[1:,13])
    y = y.astype(float)
    y = np.reshape(y, (len(y), 1))
    
    # Return data and outputs
    return X, y

# %%
# Load dataset
X, y = load_data("./data/Cardiovascular_Disease_Dataset.csv")

# %% [markdown]
# #### 2.3.1 View the Variables
#
# To ensure that data is loaded into the notebook correctly, it is wise to check the first element of both variables. The code below prints the first elements of the variables `X`and `y`.

# %%
# Print the first elements of X and y
print ('The first element of X is: ', X[0])
print ('The first element of y is: ', y[0])
# Out:
# The first element of X is:  [ 53.    1.    2.  171.    0.    0.    1.  147.    0.    5.3   3.    3. ]
# The first element of y is:  [1.]

# %% [markdown]
# #### 2.3.2 Check the dimensions of your variables
#
# Another way to ensure that the data has been loaded correctly is to view its dimensions. Printing the shape of `X` and `y` will show the number of examples and features in the data set. The shape of `X` should be `1000, 12`, and the shape of `Y` should be `1000, 1`.

# %%
# Print the shapes of X and y
print ('The shape of X is: ' + str(X.shape))
print ('The shape of y is: ' + str(y.shape))
# Out:
# The shape of X is: (1000, 12)
# The shape of y is: (1000, 1)

# %% [markdown]
# ### 2.4 - Data Preprocessing

# %% [markdown]
# To provide the best possible data for the model, two things should be done to the data. For numerical features, z-score normalization should be applied so that some features do not have a greater weight than others. For binary and nominal features, one-hot encoding should be used so the model can better interpret the data.

# %% [markdown]
# #### Z-Score Normalization Description
#
# For continuous valued features, z-score normalization will help ensure that each feature carries the same weight in the model. Z-score normalization is a method of feature scaling that involves using the mean and standard deviation of a feature to calculate the scaled version for each example. To calculate the scaled value for each example in feature j, use the following function.
# $$ x_{j, scaled} = \frac{x_{j} - M_{j}}{\sigma_{j}}$$
# Where $M_{j}$ is the mean of the examples in feature j, and $\sigma_{j}$ is the standard deviation.

# %% [markdown]
# #### One-Hot Encoding Description
#
# For features that are either binary or nominal, one-hot encoding will be used to provide the model with a better understanding of the data. Some features, such as gender, do not fit well in the model as a simple 1 or 0. The same applies to nominal features, where a 0, 1, 2, or 3 indicates different attributes of some feature. Instead, it may be wise to one-hot encode that feature. This involves splitting one feature into p different features, where p represents the number of distinct possible outputs. For example, instead of having 1 feature for gender (male or female), one-hot encoding uses two features. One of the features represents whether or not the patient is female and the other represents if the patient is male.

# %% [markdown]
# #### Normalizing and One-Hot Encoding Features

# %% [markdown]
# In this section, we will go through each feature and apply z-score normalization if it is numerical or apply one-hot encoding if it is binary or nominal.

# %%
# Create a new variable to store each feature added
X_new = np.empty(shape = (1000,0))

# Create temporary variables to store the new columns that will be added to X_new
tmp = np.empty(shape = (1000,1))
tmp2 = np.empty(shape = (1000,1))
tmp3 = np.empty(shape = (1000,1))
tmp4 = np.empty(shape = (1000,1))

# Feature 1 - Numeric
mean = np.mean(X[:,0], axis=0)
sigma  = np.std(X[:,0], axis=0) 
tmp = (X[:,0] - mean) / sigma
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))

# Feature 2 - Binary
for i in range(0, 1000):
    if X[i,1] == 0:
        tmp[i] = 1
        tmp2[i] = 0
    else:
        tmp[i] = 0
        tmp2[i] = 1
        
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))
X_new = np.hstack((X_new, tmp2.reshape(-1, 1)))

# Feature 3 - Nominal
for i in range(0, 1000):
    if X[i,2] == 0:
        tmp[i] = 1
        tmp2[i] = 0
        tmp3[i] = 0
        tmp4[i] = 0
    elif X[i,2] == 1:
        tmp[i] = 0
        tmp2[i] = 1
        tmp3[i] = 0
        tmp4[i] = 0
    elif X[i, 2] == 2:
        tmp[i] = 0
        tmp2[i] = 0
        tmp3[i] = 1
        tmp4[i] = 0
    else:
        tmp[i] = 0
        tmp2[i] = 0
        tmp3[i] = 0
        tmp4[i] = 1
        
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))
X_new = np.hstack((X_new, tmp2.reshape(-1, 1)))
X_new = np.hstack((X_new, tmp3.reshape(-1, 1)))
X_new = np.hstack((X_new, tmp4.reshape(-1, 1)))

# Feature 4 - Numeric
mean = np.mean(X[:,3], axis=0)
sigma  = np.std(X[:,3], axis=0) 
tmp = (X[:,3] - mean) / sigma
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))

# Feature 5 - Numeric
mean = np.mean(X[:,4], axis=0)
sigma  = np.std(X[:,4], axis=0) 
tmp = (X[:,4] - mean) / sigma
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))

# Feature 6 - Binary
for i in range(0, 1000):
    if X[i,5] == 0:
        tmp[i] = 1
        tmp2[i] = 0
    else:
        tmp[i] = 0
        tmp2[i] = 1
        
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))
X_new = np.hstack((X_new, tmp2.reshape(-1, 1)))

# Feature 7 - Nominal
for i in range(0, 1000):
    if X[i,6] == 0:
        tmp[i] = 1
        tmp2[i] = 0
        tmp3[i] = 0
    elif X[i,6] == 1:
        tmp[i] = 0
        tmp2[i] = 1
        tmp3[i] = 0
    else:
        tmp[i] = 0
        tmp2[i] = 0
        tmp3[i] = 1
        
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))
X_new = np.hstack((X_new, tmp2.reshape(-1, 1)))
X_new = np.hstack((X_new, tmp3.reshape(-1, 1)))

# Feature 8 - Numeric
mean = np.mean(X[:,7], axis=0)
sigma  = np.std(X[:,7], axis=0) 
tmp = (X[:,7] - mean) / sigma
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))

# Feature 9 - Binary
for i in range(0, 1000):
    if X[i,8] == 0:
        tmp[i] = 1
        tmp2[i] = 0
    else:
        tmp[i] = 0
        tmp2[i] = 1
        
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))
X_new = np.hstack((X_new, tmp2.reshape(-1, 1)))

# Feature 10 - Numeric
mean = np.mean(X[:,9], axis=0)
sigma  = np.std(X[:,9], axis=0) 
tmp = (X[:,9] - mean) / sigma
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))

# Feature 11 - Nominal
# Using four values because there are 0's in the dataset
for i in range(0, 1000):
    if X[i,10] == 0:
        tmp[i] = 1
        tmp2[i] = 0
        tmp3[i] = 0
        tmp4[i] = 0
    elif X[i,10] == 1:
        tmp[i] = 0
        tmp2[i] = 1
        tmp3[i] = 0
        tmp4[i] = 0
    elif X[i, 10] == 2:
        tmp[i] = 0
        tmp2[i] = 0
        tmp3[i] = 1
        tmp4[i] = 0
    else:
        tmp[i] = 0
        tmp2[i] = 0
        tmp3[i] = 0
        tmp4[i] = 1
        
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))
X_new = np.hstack((X_new, tmp2.reshape(-1, 1)))
X_new = np.hstack((X_new, tmp3.reshape(-1, 1)))
X_new = np.hstack((X_new, tmp4.reshape(-1, 1)))

# Feature 12 - Numeric
mean = np.mean(X[:,11], axis=0)
sigma  = np.std(X[:,11], axis=0) 
tmp = (X[:,11] - mean) / sigma
X_new = np.hstack((X_new, tmp.reshape(-1, 1)))

# %% [markdown]
# Now, let's print out the first element of the new, processed variable, `X_new`, and its shape.

# %%
# Printing the first element of X, and then printing the shape of X
print ('The first element of X_new is: ', X_new[0])
print ('The shape of X_new is: ' + str(X_new.shape))
# Out:
# The first element of X_new is:  [ 0.21046388  0.          1.          0.          0.          1.
#   0.          0.64283287 -2.35271743  1.          0.          0.
#   1.          0.          0.04456713  1.          0.          1.50724524
#   0.          0.          0.          1.          1.81967847]
# The shape of X_new is: (1000, 23)

# %% [markdown]
# Now, `X_new` represents the processed data from the dataset. The shape of `X_new` should be `1000, 23`.

# %% [markdown]
# ### 2.5 - Splitting the Dataset

# %% [markdown]
# Now, we are going to split the dataset into three different sets. The first set is the training set. It will contain 60% of the examples (600 examples) and be used to train the models. The second set is the cross validation set that will contain 20% of the examples (200 examples). This set will be used in cross validation to compare the different models to see which performs best. The third set is the test set and will contain the remaining 20% of the examples (200 examples). The test set will be used to test the accuracy of the final model.

# %%
# Create a list of indexes from 0 to 999
arr = list(range(len(y)))

# Calculate the lengths of each set 
data_len = len(arr)
training_len = int(data_len * 0.6) # 60%
cv_len = int(data_len * 0.2) # 20%
# The test set will include the last 20%

# Split the array of indices into different indices for each set
train_indices = arr[:training_len]
cv_indices = arr[training_len:training_len + cv_len]
test_indices = arr[training_len + cv_len:]

# Split the X and y into three different sets: training, cross validation, and testing
X_train = np.array([X_new[i] for i in train_indices])
y_train = np.array([y[i] for i in train_indices])

X_cv = np.array([X_new[i] for i in cv_indices])
y_cv = np.array([y[i] for i in cv_indices])

X_test = np.array([X_new[i] for i in test_indices])
y_test = np.array([y[i] for i in test_indices])

# %% [markdown]
# Now, let's see the shapes of the new sets.

# %%
print ('The shape of X_train is: ' + str(X_train.shape))
print ('The shape of y_train is: ' + str(y_train.shape))
print ('The shape of X_cv is: ' + str(X_cv.shape))
print ('The shape of y_cv is: ' + str(y_cv.shape))
print ('The shape of X_test is: ' + str(X_test.shape))
print ('The shape of y_test is: ' + str(y_test.shape))
# Out:
# The shape of X_train is: (600, 23)
# The shape of y_train is: (600, 1)
# The shape of X_cv is: (200, 23)
# The shape of y_cv is: (200, 1)
# The shape of X_test is: (200, 23)
# The shape of y_test is: (200, 1)

# %% [markdown]
# ## 3 - Model Selection and Implementation

# %% [markdown]
# A neural network will be used as the model for this project. The input size is 23 units to match the number of features for each example. The output layer will have 1 unit to represent the output, either heart disease absent (0) or present (1). As for the hidden layers in the middle, three seperate architectures will be tested. One with one hidden layer, one with two, and one with three. A cross validation set will be used to test which model has the best accuracy.
#
# To determine an initial architecture, the regularization and learning rate constants will be 0.1 and 0.001 respectively.
#
# The activation for the hidden layers will be ReLu, or rectified linear unit. This is almost the same as a linear activation, but any value that is below 0 is set to 0.
#
# The output activation will be linear at first. Afterwards, the sigmoid function (shown below) will be applied.
#
# $$ g(z) = \frac{1}{1+e^{-z}} $$
#
# g(z) will then be a value that is between 1 and 0. To interpret that output as a classification, a threshold, $\kappa$, will be used. In this project, $\kappa$ will equal 0.5.
#
# If g(z) $\ge$ $\kappa$, then prediction = 1. If g(z) < $\kappa$, then prediction = 0.

# %% [markdown]
# ### 3.1 - One Hidden Layer
#
# The first architecture that will be tested is a neural network with 1 hidden layer that consists of 15 units.
#
# <img src="images/Model1.png" style="width:400px;height:300px;">

# %%
model1 = Sequential(
    [               
        tf.keras.Input(shape=(23,)),   #specify input size
        tf.keras.layers.Dense(15, activation='relu', kernel_regularizer = tf.keras.regularizers.l2(0.1)),
        tf.keras.layers.Dense(1, activation='linear')
    ], name = "my_model1" 
)

# %% [markdown]
# Next, we will compile the model and specify the loss function and the optimizer.

# %%
model1.compile(
    loss=tf.keras.losses.BinaryCrossentropy(from_logits = True),
    optimizer=tf.keras.optimizers.Adam(0.001),
)

model1.fit(
    X_train,y_train,
    epochs=100
)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.3274
# Epoch 2/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.0874
# Epoch 3/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.8774
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.6928
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.5303
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.3878
# Epoch 7/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.2619
# Epoch 8/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.1502
# Epoch 9/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.0518
# Epoch 10/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.9637
# Epoch 11/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.8863
# Epoch 12/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.8172
# Epoch 13/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7566
# Epoch 14/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7020
# Epoch 15/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6529
# Epoch 16/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6100
# Epoch 17/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5720
# Epoch 18/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5390
# Epoch 19/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5096
# Epoch 20/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4838
# Epoch 21/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4615
# Epoch 22/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4421
# Epoch 23/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4247
# Epoch 24/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4104
# Epoch 25/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3978
# Epoch 26/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3860
# Epoch 27/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3759
# Epoch 28/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3663
# Epoch 29/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3589
# Epoch 30/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3519
# Epoch 31/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3456
# Epoch 32/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3397
# Epoch 33/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3350
# Epoch 34/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3304
# Epoch 35/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3260
# Epoch 36/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3222
# Epoch 37/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3186
# Epoch 38/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3148
# Epoch 39/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3122
# Epoch 40/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3087
# Epoch 41/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3061
# Epoch 42/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3031
# Epoch 43/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3005
# Epoch 44/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2984
# Epoch 45/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2961
# Epoch 46/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2936
# Epoch 47/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2915
# Epoch 48/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2895
# Epoch 49/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2873
# Epoch 50/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2855
# Epoch 51/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2839
# Epoch 52/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2823
# Epoch 53/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2802
# Epoch 54/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2788
# Epoch 55/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2774
# Epoch 56/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2762
# Epoch 57/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2739
# Epoch 58/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2727
# Epoch 59/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2712
# Epoch 60/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2698
# Epoch 61/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2681
# Epoch 62/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2669
# Epoch 63/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2655
# Epoch 64/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2639
# Epoch 65/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2632
# Epoch 66/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2618
# Epoch 67/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2608
# Epoch 68/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2599
# Epoch 69/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2584
# Epoch 70/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2576
# Epoch 71/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2563
# Epoch 72/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2557
# Epoch 73/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2546
# Epoch 74/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2526
# Epoch 75/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2523
# Epoch 76/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2520
# Epoch 77/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2500
# Epoch 78/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2494
# Epoch 79/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2485
# Epoch 80/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2467
# Epoch 81/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2476
# Epoch 82/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2459
# Epoch 83/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2456
# Epoch 84/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2447
# Epoch 85/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2433
# Epoch 86/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2425
# Epoch 87/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2431
# Epoch 88/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2405
# Epoch 89/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2395
# Epoch 90/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2389
# Epoch 91/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2376
# Epoch 92/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2368
# Epoch 93/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2365
# Epoch 94/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2361
# Epoch 95/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2366
# Epoch 96/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2341
# Epoch 97/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2355
# Epoch 98/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2333
# Epoch 99/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2321
# Epoch 100/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2314

# %% [markdown]
# Then, we will test the accuracy on the training and cross validation sets.

# %%
# Calculate and print the training accuracy
logit1train = model1(X_train)
p1train = tf.nn.sigmoid(logit1train)
trainAcc1 = np.mean((p1train>=0.5) == y_train) * 100
print('Train Accuracy: %f'%trainAcc1)

# Calculate and print the cross validation accuracy
logit1cv = model1(X_cv)
p1cv = tf.nn.sigmoid(logit1cv)
cvAcc1 = np.mean((p1cv>=0.5) == y_cv) * 100
print('CV Accuracy: %f'%cvAcc1)
# Out:
# Train Accuracy: 96.166667
# CV Accuracy: 96.500000

# %% [markdown]
# ### 3.2 - Two Hidden Layers
#
# The second architecture that will be tested is a neural network with 2 hidden layers. The first will consist of 15 units and the second will consist of 10 units.
#
# <img src="images/Model2.png" style="width:550px;height:300px;">

# %%
model2 = Sequential(
    [               
        tf.keras.Input(shape=(23,)),   #specify input size
        tf.keras.layers.Dense(15, activation='relu', kernel_regularizer = tf.keras.regularizers.l2(0.1)),
        tf.keras.layers.Dense(10, activation='relu', kernel_regularizer = tf.keras.regularizers.l2(0.1)),
        tf.keras.layers.Dense(1, activation='linear')
    ], name = "my_model2" 
)

# %% [markdown]
# Next, we will compile the model and specify the loss function and the optimizer.

# %%
model2.compile(
    loss=tf.keras.losses.BinaryCrossentropy(from_logits = True),
    optimizer=tf.keras.optimizers.Adam(0.001),
)

model2.fit(
    X_train,y_train,
    epochs=100
)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.5818
# Epoch 2/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.2048
# Epoch 3/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8686
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.5701
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.3044
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.0681
# Epoch 7/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.8574
# Epoch 8/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.6692
# Epoch 9/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.5021
# Epoch 10/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.3562
# Epoch 11/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.2296
# Epoch 12/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.1184
# Epoch 13/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.0225
# Epoch 14/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.9392
# Epoch 15/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.8656
# Epoch 16/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.8028
# Epoch 17/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7484
# Epoch 18/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7012
# Epoch 19/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6607
# Epoch 20/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6247
# Epoch 21/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5937
# Epoch 22/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5676
# Epoch 23/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5445
# Epoch 24/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5244
# Epoch 25/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5071
# Epoch 26/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4917
# Epoch 27/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4788
# Epoch 28/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4674
# Epoch 29/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4576
# Epoch 30/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4488
# Epoch 31/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4413
# Epoch 32/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4345
# Epoch 33/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4282
# Epoch 34/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4226
# Epoch 35/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4181
# Epoch 36/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4137
# Epoch 37/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4095
# Epoch 38/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4058
# Epoch 39/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4031
# Epoch 40/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4005
# Epoch 41/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3971
# Epoch 42/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3942
# Epoch 43/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3915
# Epoch 44/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3885
# Epoch 45/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3866
# Epoch 46/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3849
# Epoch 47/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3822
# Epoch 48/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3818
# Epoch 49/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3790
# Epoch 50/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3772
# Epoch 51/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3757
# Epoch 52/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3734
# Epoch 53/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3739
# Epoch 54/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3722
# Epoch 55/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3695
# Epoch 56/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3679
# Epoch 57/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3662
# Epoch 58/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3645
# Epoch 59/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3644
# Epoch 60/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3617
# Epoch 61/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3607
# Epoch 62/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3587
# Epoch 63/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3581
# Epoch 64/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3566
# Epoch 65/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3555
# Epoch 66/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3544
# Epoch 67/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3532
# Epoch 68/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3513
# Epoch 69/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3513
# Epoch 70/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3503
# Epoch 71/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3489
# Epoch 72/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3471
# Epoch 73/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3466
# Epoch 74/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3453
# Epoch 75/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3436
# Epoch 76/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3439
# Epoch 77/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3421
# Epoch 78/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3408
# Epoch 79/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3416
# Epoch 80/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3408
# Epoch 81/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3379
# Epoch 82/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3374
# Epoch 83/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3371
# Epoch 84/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3359
# Epoch 85/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3373
# Epoch 86/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3340
# Epoch 87/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3362
# Epoch 88/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3358
# Epoch 89/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3314
# Epoch 90/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3305
# Epoch 91/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3300
# Epoch 92/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3292
# Epoch 93/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3284
# Epoch 94/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3278
# Epoch 95/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3279
# Epoch 96/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3261
# Epoch 97/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3250
# Epoch 98/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3248
# Epoch 99/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3243
# Epoch 100/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3243

# %% [markdown]
# Then, we will test the accuracy on the training and cross validation sets.

# %%
# Calculate and print the training accuracy
logit2train = model2(X_train)
p2train = tf.nn.sigmoid(logit2train)
trainAcc2 = np.mean((p2train>=0.5) == y_train) * 100
print('Train Accuracy: %f'%trainAcc2)

# Calculate and print the cross validation accuracy
logit2cv = model2(X_cv)
p2cv = tf.nn.sigmoid(logit2cv)
cvAcc2 = np.mean((p2cv>=0.5) == y_cv) * 100
print('CV Accuracy: %f'%cvAcc2)
# Out:
# Train Accuracy: 96.000000
# CV Accuracy: 96.500000

# %% [markdown]
# ### 3.3 - Three Hidden Layers
#
# The third architecture that will be tested is a neural network with 3 hidden layers. The first will consist of 15 units, the second will have 10 units, and the third will have 5 units.
#
# <img src="images/Model3.png" style="width:700px;height:300px;">

# %%
model3 = Sequential(
    [               
        tf.keras.Input(shape=(23,)),   #specify input size
        tf.keras.layers.Dense(15, activation='relu', kernel_regularizer = tf.keras.regularizers.l2(0.1)),
        tf.keras.layers.Dense(10, activation='relu', kernel_regularizer = tf.keras.regularizers.l2(0.1)),
        tf.keras.layers.Dense(5, activation='relu', kernel_regularizer = tf.keras.regularizers.l2(0.1)),
        tf.keras.layers.Dense(1, activation='linear')
    ], name = "my_model3" 
)

# %% [markdown]
# Next, we will compile the model and specify the loss function and the optimizer.

# %%
model3.compile(
    loss=tf.keras.losses.BinaryCrossentropy(from_logits = True),
    optimizer=tf.keras.optimizers.Adam(0.001),
)

model3.fit(
    X_train,y_train,
    epochs=100
)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 2ms/step - loss: 4.5750
# Epoch 2/100
# 19/19 [==============================] - 0s 2ms/step - loss: 4.1241
# Epoch 3/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.7213
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.3635
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.0455
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7628
# Epoch 7/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.5117
# Epoch 8/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.2887
# Epoch 9/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.0903
# Epoch 10/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.9144
# Epoch 11/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.7583
# Epoch 12/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.6202
# Epoch 13/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.4983
# Epoch 14/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.3911
# Epoch 15/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.2969
# Epoch 16/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.2144
# Epoch 17/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.1426
# Epoch 18/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.0802
# Epoch 19/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.0263
# Epoch 20/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.9792
# Epoch 21/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.9384
# Epoch 22/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.9029
# Epoch 23/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.8720
# Epoch 24/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.8447
# Epoch 25/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.8212
# Epoch 26/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.8007
# Epoch 27/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7820
# Epoch 28/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7659
# Epoch 29/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7509
# Epoch 30/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7372
# Epoch 31/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7250
# Epoch 32/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7132
# Epoch 33/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7025
# Epoch 34/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6916
# Epoch 35/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6809
# Epoch 36/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6714
# Epoch 37/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6614
# Epoch 38/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6516
# Epoch 39/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6438
# Epoch 40/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6347
# Epoch 41/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6268
# Epoch 42/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6177
# Epoch 43/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6108
# Epoch 44/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6043
# Epoch 45/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5971
# Epoch 46/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5909
# Epoch 47/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5857
# Epoch 48/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5808
# Epoch 49/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5785
# Epoch 50/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5736
# Epoch 51/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5684
# Epoch 52/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5646
# Epoch 53/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5606
# Epoch 54/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5567
# Epoch 55/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5541
# Epoch 56/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5521
# Epoch 57/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5489
# Epoch 58/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5450
# Epoch 59/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5420
# Epoch 60/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5393
# Epoch 61/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5371
# Epoch 62/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5348
# Epoch 63/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5323
# Epoch 64/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5300
# Epoch 65/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5291
# Epoch 66/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5265
# Epoch 67/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5246
# Epoch 68/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5222
# Epoch 69/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5203
# Epoch 70/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5189
# Epoch 71/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5194
# Epoch 72/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5162
# Epoch 73/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5143
# Epoch 74/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5114
# Epoch 75/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5101
# Epoch 76/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5081
# Epoch 77/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5067
# Epoch 78/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5056
# Epoch 79/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5040
# Epoch 80/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5029
# Epoch 81/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5014
# Epoch 82/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5002
# Epoch 83/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4993
# Epoch 84/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4974
# Epoch 85/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4960
# Epoch 86/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4952
# Epoch 87/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4935
# Epoch 88/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4929
# Epoch 89/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4913
# Epoch 90/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4897
# Epoch 91/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4898
# Epoch 92/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4882
# Epoch 93/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4873
# Epoch 94/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4858
# Epoch 95/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4847
# Epoch 96/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4835
# Epoch 97/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4824
# Epoch 98/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4815
# Epoch 99/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4815
# Epoch 100/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4801

# %% [markdown]
# Then, we will test the accuracy on the training and cross validation sets.

# %%
# Calculate and print the training accuracy
logit3train = model3(X_train)
p3train = tf.nn.sigmoid(logit3train)
trainAcc3 = np.mean((p3train>=0.5) == y_train) * 100
print('Train Accuracy: %f'%trainAcc3)

# Calculate and print the cross validation accuracy
logit3cv = model3(X_cv)
p3cv = tf.nn.sigmoid(logit3cv)
cvAcc3 = np.mean((p3cv>=0.5) == y_cv) * 100
print('CV Accuracy: %f'%cvAcc3)
# Out:
# Train Accuracy: 94.666667
# CV Accuracy: 93.500000

# %% [markdown]
# ### 3.4 - Comparing the Architectures
#
# When running the code, these are the results that I got. I tried to make a fancy plot that would graph the current values, but matplot kept killing my terminal.
#
# | # of Hidden Layers | Training Accuracy | CV Accuracy |
# |--------------------|-------------------|-------------|
# | 1 Hidden Layer     | 96.1667           | 96.00       |
# | 2 Hidden Layers    | 96.00             | 95.00       |
# | 3 Hidden Layers    | 95.166            | 95.00       |
#
# Surpisingly, the architecture with only 1 hidden layer performed the best in both training accuracy and cross validation accuracy. There likely was not enough data in the training set to fine tune the parameters in the larger neural networks. However, all of these accuracies are acceptable, so it does not seem like a bug.

# %% [markdown]
# ## 4 - Regularization and Parameter Tuning
#
# Now that the architecture has been decided, we are going to fine tune the regularization parameter. The Adam optimization algorithm alters the learning rate between each epoch depending on the change in the loss function values. Since the learning rate is dynamically changed, this value does not require tuning.

# %% [markdown]
# ### Regularization Tuning
#
# This code below will test different regularization parameter values and then output the training and cross validation accuracies for each. Note: plotting is not used because matplot keeps killing my terminal.

# %%
lambdas = [0.0, 0.001, 0.01, 0.05, 0.1, 0.2, 0.3]
models=[None] * len(lambdas)
for i in range(len(lambdas)):
    lambda_ = lambdas[i]
    models[i] =  Sequential(
        [
        tf.keras.Input(shape=(23,)),   #specify input size
        tf.keras.layers.Dense(15, activation='relu', kernel_regularizer = tf.keras.regularizers.l2(0.1)),
        tf.keras.layers.Dense(1, activation='linear')
        ]
    )
    models[i].compile(
        loss=tf.keras.losses.BinaryCrossentropy(from_logits = True),
        optimizer=tf.keras.optimizers.Adam(0.001),
    )

    models[i].fit(
        X_train, y_train,
        epochs=100
    )
# Out:
# Epoch 1/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.3900
# Epoch 2/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.1430
# Epoch 3/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.9278
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.7403
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.5763
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.4310
# Epoch 7/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.3012
# Epoch 8/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.1842
# Epoch 9/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.0785
# Epoch 10/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.9829
# Epoch 11/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.8964
# Epoch 12/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.8177
# Epoch 13/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7477
# Epoch 14/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6862
# Epoch 15/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6323
# Epoch 16/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5869
# Epoch 17/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5471
# Epoch 18/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5124
# Epoch 19/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4830
# Epoch 20/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4577
# Epoch 21/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4362
# Epoch 22/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4173
# Epoch 23/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4015
# Epoch 24/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3880
# Epoch 25/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3769
# Epoch 26/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3663
# Epoch 27/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3577
# Epoch 28/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3505
# Epoch 29/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3430
# Epoch 30/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3377
# Epoch 31/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3327
# Epoch 32/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3280
# Epoch 33/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.
100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2908
# Epoch 52/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2897
# Epoch 53/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2874
# Epoch 54/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2857
# Epoch 55/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2839
# Epoch 56/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2820
# Epoch 57/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2802
# Epoch 58/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2797
# Epoch 59/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2784
# Epoch 60/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2766
# Epoch 61/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2746
# Epoch 62/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2732
# Epoch 63/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2719
# Epoch 64/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2711
# Epoch 65/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2697
# Epoch 66/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2677
# Epoch 67/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2673
# Epoch 68/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2662
# Epoch 69/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2643
# Epoch 70/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2632
# Epoch 71/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2619
# Epoch 72/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2620
# Epoch 73/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2594
# Epoch 74/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2590
# Epoch 75/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2581
# Epoch 76/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2564
# Epoch 77/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2555
# Epoch 78/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2546
# Epoch 79/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2525
# Epoch 80/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2518
# Epoch 81/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2515
# Epoch 82/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2511
# Epoch 83/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2492
# Epoch 84/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2504
# Epoch 85/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2498
# Epoch 86/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2498
# Epoch 87/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2454
# Epoch 88/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2450
# Epoch 89/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2449
# Epoch 90/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2452
# Epoch 91/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2430
# Epoch 92/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2416
# Epoch 93/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2402
# Epoch 94/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2396
# Epoch 95/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2389
# Epoch 96/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2381
# Epoch 97/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2378
# Epoch 98/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2369
# Epoch 99/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2358
# Epoch 100/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2351

# %% [markdown]
# ### Results and Decision
#
# This code will print out the training and cross valudation accuracies for the prior test.

# %%
for i in range(len(lambdas)):
    lambda_ = lambdas[i]
    print(f"Lambda = {lambda_}")
    # Calculate and print the training accuracy
    logitTrain = models[i](X_train)
    pTrain = tf.nn.sigmoid(logitTrain)
    trainAcc = np.mean((pTrain>=0.5) == y_train) * 100
    print('Train Accuracy: %f'%trainAcc)

    # Calculate and print the cross validation accuracy
    logitCV = models[i](X_cv)
    pCV = tf.nn.sigmoid(logitCV)
    cvAcc = np.mean((pCV>=0.5) == y_cv) * 100
    print('CV Accuracy: %f'%cvAcc)
    
    print('\n')
# Out:
# Lambda = 0.0
# Train Accuracy: 96.166667
# CV Accuracy: 96.500000
#
#
# Lambda = 0.001
# Train Accuracy: 96.000000
# CV Accuracy: 95.000000
#
#
# Lambda = 0.01
# Train Accuracy: 96.000000
# CV Accuracy: 96.000000
#
#
# Lambda = 0.05
# Train Accuracy: 96.166667
# CV Accuracy: 96.500000
#
#
# Lambda = 0.1
# Train Accuracy: 96.166667
# CV Accuracy: 96.000000
#
#
# Lambda = 0.2
# Train Accuracy: 96.166667
# CV Accuracy: 96.500000
#
#
# Lambda = 0.3
# Train Accuracy: 96.000000
# CV Accuracy: 96.500000

# %% [markdown]
# The following table shows the results that I achieved. The difference is the magnitude of the difference between the training accuracy and the cross validation accuracy.
#
# | Lambda | Training Accuracy | CV Accuracy | Difference |
# |--------|-------------------|-------------|------------|
# | 0.0    | 96.1667           | 95.5        | 0.667      |
# | 0.001  | 96.1667           | 96.0        | 0.1667     |
# | 0.01   | 96.1667           | 96.5        | 0.33       |
# | 0.05   | 96.1667           | 96.0        | 0.1667     |
# | 0.1    | 96.1667           | 96.5        | 0.33       |
# | 0.2    | 96.33             | 97.0        | 0.667      |
# | 0.3    | 96.1667           | 96.5        | 0.33       |
#
# The lambda values with the smallest difference appears to be 0.001 and 0.05. I chose lambda = 0.05 for the regularization parameter because having a larger regularization parameter will reduce the chances that the model is overfitting.
#
# $$ \lambda = 0.05$$

# %% [markdown]
# ## 5 - Evaluation
#
# First, let's build a fresh model with the decided architecture and regularization parameter.

# %% [markdown]
# ### 5.1 - Build Model

# %%
finalModel =  Sequential(
    [
    tf.keras.Input(shape=(23,)),   #specify input size
    tf.keras.layers.Dense(15, activation='relu', kernel_regularizer = tf.keras.regularizers.l2(0.05)),
    tf.keras.layers.Dense(1, activation='linear')
    ]
)

finalModel.compile(
    loss=tf.keras.losses.BinaryCrossentropy(from_logits = True),
    optimizer=tf.keras.optimizers.Adam(0.001),
)

finalModel.fit(
    X_train, y_train,
    epochs=100
)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.6401
# Epoch 2/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.4769
# Epoch 3/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.3342
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.2097
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.0989
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 1.0026
# Epoch 7/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.9171
# Epoch 8/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.8418
# Epoch 9/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7749
# Epoch 10/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7161
# Epoch 11/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6640
# Epoch 12/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6181
# Epoch 13/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5770
# Epoch 14/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5417
# Epoch 15/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5099
# Epoch 16/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4819
# Epoch 17/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4575
# Epoch 18/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4354
# Epoch 19/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4159
# Epoch 20/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3989
# Epoch 21/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3838
# Epoch 22/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3695
# Epoch 23/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3574
# Epoch 24/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3464
# Epoch 25/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3368
# Epoch 26/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3276
# Epoch 27/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3202
# Epoch 28/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3129
# Epoch 29/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3073
# Epoch 30/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3013
# Epoch 31/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2972
# Epoch 32/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2919
# Epoch 33/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2881
# Epoch 34/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2838
# Epoch 35/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2805
# Epoch 36/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2771
# Epoch 37/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2739
# Epoch 38/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2713
# Epoch 39/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2687
# Epoch 40/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2661
# Epoch 41/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2639
# Epoch 42/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2617
# Epoch 43/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2589
# Epoch 44/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2574
# Epoch 45/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2562
# Epoch 46/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2544
# Epoch 47/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2519
# Epoch 48/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2501
# Epoch 49/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2500
# Epoch 50/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2473
# Epoch 51/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2460
# Epoch 52/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2437
# Epoch 53/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2426
# Epoch 54/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2412
# Epoch 55/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2398
# Epoch 56/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2387
# Epoch 57/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2373
# Epoch 58/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2360
# Epoch 59/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2349
# Epoch 60/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2334
# Epoch 61/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2318
# Epoch 62/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2306
# Epoch 63/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2298
# Epoch 64/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2288
# Epoch 65/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2288
# Epoch 66/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2269
# Epoch 67/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2260
# Epoch 68/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2243
# Epoch 69/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2234
# Epoch 70/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2222
# Epoch 71/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2206
# Epoch 72/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2196
# Epoch 73/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2195
# Epoch 74/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2177
# Epoch 75/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2169
# Epoch 76/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2161
# Epoch 77/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2152
# Epoch 78/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2141
# Epoch 79/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2131
# Epoch 80/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2131
# Epoch 81/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2120
# Epoch 82/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2112
# Epoch 83/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2103
# Epoch 84/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2092
# Epoch 85/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2080
# Epoch 86/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2077
# Epoch 87/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2081
# Epoch 88/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2051
# Epoch 89/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2056
# Epoch 90/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2038
# Epoch 91/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2047
# Epoch 92/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2056
# Epoch 93/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2018
# Epoch 94/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2012
# Epoch 95/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2005
# Epoch 96/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2003
# Epoch 97/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1998
# Epoch 98/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1998
# Epoch 99/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1982
# Epoch 100/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1971

# %% [markdown]
# ### 5.2 - Calculate Testing Accuracy
#
# Now, let's the accuracy using the test set that was created earlier.

# %%
# Calculate and print the testing accuracy
logitTest = finalModel(X_test)
pTest = tf.nn.sigmoid(logitTest)
testAcc = np.mean((pTest>=0.5) == y_test) * 100
print('Test Accuracy: %f'%testAcc)
# Out:
# Test Accuracy: 95.500000

# %% [markdown]
# When I ran the code, I had a test accuracy of 95.5.

# %% [markdown]
# ### 5.3 - Calculate Precision, Recall, and F1 Score
#
# To gain a better understanding of the accuracy of the model, we are going to calculate the precision, recall, and F1 score.
#
# The precision will tell us what fraction of the patients we predicted to have heart disease actually have heart disease. True positives indicate the number of examples that were predicted positive and were actually positive. Predicted Positives is the total number of positive predictions from the model.
# $$ precision = \frac{True Positives}{Predicted Positives} $$
#
# The recall will tell us what fraction of the patients that had heart disease were number predicted correctly. Actual Positives refer to the total number of patients that has heart disease in the dataset.
# $$ recall = \frac{True Positives}{Actual Positives} $$
#
# The F1 score, also known as the harmonic mean, is a good way to compare precision and recall numbers.
# $$ F1 = \frac{2*precision*recall}{precision + recall} $$

# %%
# Containers to hold the predicted, actual, and true positives
predictedPositives = 0
actualPositives = 0
truePositives = 0

# Count the number of predicted, actual, and true positives
for i in range(0, len(y_test)):
    prediction = float(pTest[i] >= 0.5)
    if y_test[i] == 1:
        actualPositives += 1
    if prediction == 1:
        predictedPositives += 1
    if y_test[i] == prediction and prediction == 1:
        truePositives += 1
    
# Calculate the precision, recall, and F1 score
precision = truePositives / predictedPositives
recall = truePositives / actualPositives
F1 = 2 * precision * recall / (precision + recall)

# Print the results
print('Precision: %f'%precision)
print('Recall: %f'%recall)
print('F1 Score: %f'%F1)
# Out:
# Precision: 0.967213
# Recall: 0.959350
# F1 Score: 0.963265

# %% [markdown]
# #### Results
#
# When running the code, I got the following values:
# Precision: 0.967213
# Recall: 0.959350
# F1 Score: 0.963265
#
# This model has a great F1 score. The precision and recall were fairly close too which means that the threshold appears to be set correctly.

# %% [markdown]
# ## 6 - Analysis
#
# Overall, the model that was chosen worked great on the dataset. Much work was needed to process the data. Z-score normalization or one-hot encoding needed to be applied to each feature in the dataset seperately, depending on categorization of the data. Then, a neural network architecture was decided: 23 inputs for the processed data's features, one hidden layer with 15 units, and an output layer with 1 unit. After, the regularization parameter was tuned to 0.05 to avoid high variance.
#
# The accuracy of the model on a testing set, that is was not trained on, was 95.5%. This is a great accuracy for a model that predicts heart disease. The F1 score was 0.963265 out of 1, so the predictions were not skewed towards predicting positive or negative.
#
# Doctors could use this model to help with their decisions on whether or not a patient may have a problem with their heart. Heart disease can be life threatening, so a model that can accurately predict heart disease has the potential to save lives.
